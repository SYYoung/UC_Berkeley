# %%
from datascience import *
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')

# %%
movies = Table.read_table('../Data/top_movies_2017.csv')
movies
# Out:
# Title                            | Studio          | Gross     | Gross (Adjusted) | Year
# Gone with the Wind               | MGM             | 198676459 | 1796176700       | 1939
# Star Wars                        | Fox             | 460998007 | 1583483200       | 1977
# The Sound of Music               | Fox             | 158671368 | 1266072700       | 1965
# E.T.: The Extra-Terrestrial      | Universal       | 435110554 | 1261085000       | 1982
# Titanic                          | Paramount       | 658672302 | 1204368000       | 1997
# The Ten Commandments             | Paramount       | 65500000  | 1164590000       | 1956
# Jaws                             | Universal       | 260000000 | 1138620700       | 1975
# Doctor Zhivago                   | MGM             | 111721910 | 1103564200       | 1965
# The Exorcist                     | Warner Brothers | 232906145 | 983226600        | 1973
# ...

# %%
movies.sort('Gross', descending=True)
# Out:
# Title                                     | Studio          | Gross     | Gross (Adjusted) | Year
# Star Wars: The Force Awakens              | Buena Vista     | 936662225 | 961143200        | 2015
# Avatar                                    | Fox             | 760507625 | 865082100        | 2009
# Titanic                                   | Paramount       | 658672302 | 1204368000       | 1997
# Jurassic World                            | Universal       | 652270625 | 702747400        | 2015
# Marvel's The Avengers                     | Buena Vista     | 623357910 | 683474000        | 2012
# The Dark Knight                           | Warner Brothers | 534858444 | 661980500        | 2008
# Rogue One: A Star Wars Story              | Buena Vista     | 532177324 | 537326000        | 2016
# Beauty and the Beast (2017)               | Buena Vista     | 504014165 | 504014165        | 2017
# Finding Dory                              | Buena Vista     | 486295561 | 499245400        | 2016
# ...

# %%
movies.set_format('Gross', NumberFormatter)
# Out:
# Title                            | Studio          | Gross       | Gross (Adjusted) | Year
# Gone with the Wind               | MGM             | 198,676,459 | 1796176700       | 1939
# Star Wars                        | Fox             | 460,998,007 | 1583483200       | 1977
# The Sound of Music               | Fox             | 158,671,368 | 1266072700       | 1965
# E.T.: The Extra-Terrestrial      | Universal       | 435,110,554 | 1261085000       | 1982
# Titanic                          | Paramount       | 658,672,302 | 1204368000       | 1997
# The Ten Commandments             | Paramount       | 65,500,000  | 1164590000       | 1956
# Jaws                             | Universal       | 260,000,000 | 1138620700       | 1975
# Doctor Zhivago                   | MGM             | 111,721,910 | 1103564200       | 1965
# The Exorcist                     | Warner Brothers | 232,906,145 | 983226600        | 1973
# ...

# %%
movies.set_format('Gross (Adjusted)', NumberFormatter)
# Out:
# Title                            | Studio          | Gross       | Gross (Adjusted) | Year
# Gone with the Wind               | MGM             | 198,676,459 | 1,796,176,700    | 1939
# Star Wars                        | Fox             | 460,998,007 | 1,583,483,200    | 1977
# The Sound of Music               | Fox             | 158,671,368 | 1,266,072,700    | 1965
# E.T.: The Extra-Terrestrial      | Universal       | 435,110,554 | 1,261,085,000    | 1982
# Titanic                          | Paramount       | 658,672,302 | 1,204,368,000    | 1997
# The Ten Commandments             | Paramount       | 65,500,000  | 1,164,590,000    | 1956
# Jaws                             | Universal       | 260,000,000 | 1,138,620,700    | 1975
# Doctor Zhivago                   | MGM             | 111,721,910 | 1,103,564,200    | 1965
# The Exorcist                     | Warner Brothers | 232,906,145 | 983,226,600      | 1973
# ...

# %%
adjustment = movies.column("Gross (Adjusted)") / movies.column("Gross")

# %%
movies.with_column("Adjustment", adjustment)
# Out:
# Title                            | Studio          | Gross       | Gross (Adjusted) | Year | Adjustment
# Gone with the Wind               | MGM             | 198,676,459 | 1,796,176,700    | 1939 | 9.04071
# Star Wars                        | Fox             | 460,998,007 | 1,583,483,200    | 1977 | 3.4349
# The Sound of Music               | Fox             | 158,671,368 | 1,266,072,700    | 1965 | 7.97921
# E.T.: The Extra-Terrestrial      | Universal       | 435,110,554 | 1,261,085,000    | 1982 | 2.89831
# Titanic                          | Paramount       | 658,672,302 | 1,204,368,000    | 1997 | 1.82848
# The Ten Commandments             | Paramount       | 65,500,000  | 1,164,590,000    | 1956 | 17.78
# Jaws                             | Universal       | 260,000,000 | 1,138,620,700    | 1975 | 4.37931
# Doctor Zhivago                   | MGM             | 111,721,910 | 1,103,564,200    | 1965 | 9.87778
# ...

# %%
movies.with_column("Adjustment", adjustment).scatter('Year', 'Adjustment')

# %%
movies.num_rows
# Out:
# 200

# %%
min(movies.column("Gross (Adjusted)"))
# Out:
# 338409100

# %%
movies.select('Title', 'Gross (Adjusted)')
# Out:
# Title                            | Gross (Adjusted)
# Gone with the Wind               | 1,796,176,700
# Star Wars                        | 1,583,483,200
# The Sound of Music               | 1,266,072,700
# E.T.: The Extra-Terrestrial      | 1,261,085,000
# Titanic                          | 1,204,368,000
# The Ten Commandments             | 1,164,590,000
# Jaws                             | 1,138,620,700
# Doctor Zhivago                   | 1,103,564,200
# The Exorcist                     | 983,226,600
# Snow White and the Seven Dwarves | 969,010,000
# ... (190 rows omitted)

# %%
tmp1 = "a"
tmp1
# Out:
# 'a'

# %%
int('123') + 4
# Out:
# 127

# %%
help(Table.with_columns)
# Out:
# Help on function with_columns in module datascience.tables:
#
# with_columns(self, *labels_and_values, **formatter)
#     Return a table with additional or replaced columns.
#
#
#     Args:
#         ``labels_and_values``: An alternating list of labels and values
#             or a list of label-value pairs. If one of the labels is in
#             existing table, then every value in the corresponding column is
#             set to that value. If label has only a single value (``int``),
#             every row of corresponding column takes on that value.
#         ''formatter'' (single Formatter value): A single formatter value
#             that will be applied to all columns being added using this
#             function call.
#
#     Raises:
#         ``ValueError``: If
#             - any label in ``labels_and_values`` is not a valid column
#                 name, i.e if label is not of type (str).
#             - if any value in ``labels_and_values`` is a list/array and
# ...

# %%
minard = Table.read_table('../Data/minard.csv')

# %%
minard
# Out:
# Longitude | Latitude | City        | Direction | Survivors
# 32        | 54.8     | Smolensk    | Advance   | 145000
# 33.2      | 54.9     | Dorogobouge | Advance   | 140000
# 34.4      | 55.5     | Chjat       | Advance   | 127100
# 37.6      | 55.8     | Moscou      | Advance   | 100000
# 34.3      | 55.2     | Wixma       | Retreat   | 55000
# 32        | 54.6     | Smolensk    | Retreat   | 24000
# 30.4      | 54.4     | Orscha      | Retreat   | 20000
# 26.8      | 54.3     | Moiodexno   | Retreat   | 12000

# %%
minard.labels
# Out:
# ('Longitude', 'Latitude', 'City', 'Direction', 'Survivors')

# %%
make_array(2, 'a')
# Out:
# array(['2', 'a'], dtype='<U21')

# %%
flowers = Table.read_table('../Data/flowers.csv')

# %%
flowers
# Out:
# Petals | Name      | Color
# 8      | lotus     | pink
# 34     | sunflower | yellow
# 5      | rose      | red

# %%
minard.take(0)
# Out:
# Longitude | Latitude | City     | Direction | Survivors
# 32        | 54.8     | Smolensk | Advance   | 145000

# %%
minard.take([0, 2, 3])
# Out:
# Longitude | Latitude | City     | Direction | Survivors
# 32        | 54.8     | Smolensk | Advance   | 145000
# 34.4      | 55.5     | Chjat    | Advance   | 127100
# 37.6      | 55.8     | Moscou   | Advance   | 100000

# %%
minard.take([0:3])
# Out:
#   File "<ipython-input-38-247e1aa25bc5>", line 1
#     minard.take([0:3])
#                   ^
# SyntaxError: invalid syntax

# %%
np.arange(0,4)
# Out:
# array([0, 1, 2, 3])

# %%
minard.take(np.arange(0,5))
# Out:
# Longitude | Latitude | City        | Direction | Survivors
# 32        | 54.8     | Smolensk    | Advance   | 145000
# 33.2      | 54.9     | Dorogobouge | Advance   | 140000
# 34.4      | 55.5     | Chjat       | Advance   | 127100
# 37.6      | 55.8     | Moscou      | Advance   | 100000
# 34.3      | 55.2     | Wixma       | Retreat   | 55000

# %%
nba = Table.read_table('../Data/nba_salaries.csv')
nba
# Out:
# PLAYER           | POSITION | TEAM          | 2015-2016 SALARY
# Paul Millsap     | PF       | Atlanta Hawks | 18.6717
# Al Horford       | C        | Atlanta Hawks | 12
# Tiago Splitter   | C        | Atlanta Hawks | 9.75625
# Jeff Teague      | PG       | Atlanta Hawks | 8
# Kyle Korver      | SG       | Atlanta Hawks | 5.74648
# Thabo Sefolosha  | SF       | Atlanta Hawks | 4
# Mike Scott       | PF       | Atlanta Hawks | 3.33333
# Kent Bazemore    | SF       | Atlanta Hawks | 2
# Dennis Schroder  | PG       | Atlanta Hawks | 1.7634
# Tim Hardaway Jr. | SG       | Atlanta Hawks | 1.30452
# ... (407 rows omitted)

# %%
nba.sort('2015-2016 SALARY', descending=True)
# Out:
# PLAYER          | POSITION | TEAM                  | 2015-2016 SALARY
# Kobe Bryant     | SF       | Los Angeles Lakers    | 25
# Joe Johnson     | SF       | Brooklyn Nets         | 24.8949
# LeBron James    | SF       | Cleveland Cavaliers   | 22.9705
# Carmelo Anthony | SF       | New York Knicks       | 22.875
# Dwight Howard   | C        | Houston Rockets       | 22.3594
# Chris Bosh      | PF       | Miami Heat            | 22.1927
# Chris Paul      | PG       | Los Angeles Clippers  | 21.4687
# Kevin Durant    | SF       | Oklahoma City Thunder | 20.1586
# Derrick Rose    | PG       | Chicago Bulls         | 20.0931
# Dwyane Wade     | SG       | Miami Heat            | 20
# ... (407 rows omitted)

# %%
nba = nba.relabeled('2015-2016 SALARY' 'SALARY')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-0a56e4f6c67a> in <module>
# ----> 1 nba = nba.relabeled('2015-2016 SALARY' 'SALARY')
#
# TypeError: relabeled() missing 1 required positional argument: 'new_label'

# %%
nba = nba.relabelled('2015-2016 SALARY', 'SALARY')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-f7419795f697> in <module>
# ----> 1 nba = nba.relabelled('2015-2016 SALARY', 'SALARY')
#
# ~/anaconda3/lib/python3.7/site-packages/datascience/tables.py in __getattr__(self, attr)
#     233         else:
#     234             msg = "'{0}' object has no attribute '{1}'".format(type(self).__name__, attr)
# --> 235             raise AttributeError(msg)
#     236
#     237     ####################
#
# AttributeError: 'Table' object has no attribute 'relabelled'

# %%
nba = nba.relabeled('2015-2016 SALARY', 'SALARY')

# %%
nba
# Out:
# PLAYER           | POSITION | TEAM          | SALARY
# Paul Millsap     | PF       | Atlanta Hawks | 18.6717
# Al Horford       | C        | Atlanta Hawks | 12
# Tiago Splitter   | C        | Atlanta Hawks | 9.75625
# Jeff Teague      | PG       | Atlanta Hawks | 8
# Kyle Korver      | SG       | Atlanta Hawks | 5.74648
# Thabo Sefolosha  | SF       | Atlanta Hawks | 4
# Mike Scott       | PF       | Atlanta Hawks | 3.33333
# Kent Bazemore    | SF       | Atlanta Hawks | 2
# Dennis Schroder  | PG       | Atlanta Hawks | 1.7634
# Tim Hardaway Jr. | SG       | Atlanta Hawks | 1.30452
# ... (407 rows omitted)

# %%
nba.where('SALARY', are.above(10))
# Out:
# PLAYER         | POSITION | TEAM              | SALARY
# Paul Millsap   | PF       | Atlanta Hawks     | 18.6717
# Al Horford     | C        | Atlanta Hawks     | 12
# Joe Johnson    | SF       | Brooklyn Nets     | 24.8949
# Thaddeus Young | PF       | Brooklyn Nets     | 11.236
# Al Jefferson   | C        | Charlotte Hornets | 13.5
# Nicolas Batum  | SG       | Charlotte Hornets | 13.1253
# Kemba Walker   | PG       | Charlotte Hornets | 12
# Derrick Rose   | PG       | Chicago Bulls     | 20.0931
# Jimmy Butler   | SG       | Chicago Bulls     | 16.4075
# Joakim Noah    | C        | Chicago Bulls     | 13.4
# ... (59 rows omitted)

# %%
nba.where('SALARY', are.above(10)).sort('SALARY')
# Out:
# PLAYER          | POSITION | TEAM                 | SALARY
# DeMar DeRozan   | SG       | Toronto Raptors      | 10.05
# Gerald Wallace  | SF       | Philadelphia 76ers   | 10.1059
# Luol Deng       | SF       | Miami Heat           | 10.1516
# Monta Ellis     | SG       | Indiana Pacers       | 10.3
# Wilson Chandler | SF       | Denver Nuggets       | 10.4494
# Brendan Haywood | C        | Cleveland Cavaliers  | 10.5225
# Jrue Holiday    | PG       | New Orleans Pelicans | 10.5955
# Tyreke Evans    | SG       | New Orleans Pelicans | 10.7346
# Marcin Gortat   | C        | Washington Wizards   | 11.2174
# Thaddeus Young  | PF       | Brooklyn Nets        | 11.236
# ... (59 rows omitted)

# %%
nba.where('SALARY', are.between(10,15))
# Out:
# PLAYER           | POSITION | TEAM                | SALARY
# Al Horford       | C        | Atlanta Hawks       | 12
# Thaddeus Young   | PF       | Brooklyn Nets       | 11.236
# Al Jefferson     | C        | Charlotte Hornets   | 13.5
# Nicolas Batum    | SG       | Charlotte Hornets   | 13.1253
# Kemba Walker     | PG       | Charlotte Hornets   | 12
# Joakim Noah      | C        | Chicago Bulls       | 13.4
# Tristan Thompson | C        | Cleveland Cavaliers | 14.2609
# Brendan Haywood  | C        | Cleveland Cavaliers | 10.5225
# Danilo Gallinari | SF       | Denver Nuggets      | 14
# Kenneth Faried   | PF       | Denver Nuggets      | 11.236
# ... (29 rows omitted)

# %%
nba.where('TEAM', are.equal_to('Charlotte Hornets'))
# Out:
# PLAYER                 | POSITION | TEAM              | SALARY
# Al Jefferson           | C        | Charlotte Hornets | 13.5
# Nicolas Batum          | SG       | Charlotte Hornets | 13.1253
# Kemba Walker           | PG       | Charlotte Hornets | 12
# Marvin Williams        | PF       | Charlotte Hornets | 7
# Michael Kidd-Gilchrist | SF       | Charlotte Hornets | 6.3314
# Spencer Hawes          | PF       | Charlotte Hornets | 6.11003
# Courtney Lee           | SG       | Charlotte Hornets | 5.675
# Cody Zeller            | C        | Charlotte Hornets | 4.2042
# Jeremy Lamb            | SG       | Charlotte Hornets | 3.03436
# Brian Roberts          | PG       | Charlotte Hornets | 2.85494
# ... (8 rows omitted)

# %%
nba.where('TEAM', are.containing('Charlotte')).sort('SALARY', descending=True)
# Out:
# PLAYER                 | POSITION | TEAM              | SALARY
# Al Jefferson           | C        | Charlotte Hornets | 13.5
# Nicolas Batum          | SG       | Charlotte Hornets | 13.1253
# Kemba Walker           | PG       | Charlotte Hornets | 12
# Marvin Williams        | PF       | Charlotte Hornets | 7
# Michael Kidd-Gilchrist | SF       | Charlotte Hornets | 6.3314
# Spencer Hawes          | PF       | Charlotte Hornets | 6.11003
# Courtney Lee           | SG       | Charlotte Hornets | 5.675
# Cody Zeller            | C        | Charlotte Hornets | 4.2042
# Jeremy Lamb            | SG       | Charlotte Hornets | 3.03436
# Brian Roberts          | PG       | Charlotte Hornets | 2.85494
# ... (8 rows omitted)

# %%
help(Table)
# Out:
# Help on class Table in module datascience.tables:
#
# class Table(collections.abc.MutableMapping)
#  |  Table(labels=None, formatter=<datascience.formats.Formatter object at 0x7f8ac0932da0>)
#  |
#  |  A sequence of string-labeled columns.
#  |
#  |  Method resolution order:
#  |      Table
#  |      collections.abc.MutableMapping
#  |      collections.abc.Mapping
#  |      collections.abc.Collection
#  |      collections.abc.Sized
#  |      collections.abc.Iterable
#  |      collections.abc.Container
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __delitem__(self, index_or_label)
#  |
#  |  __getattr__(self, attr)
#  |      Return a method that applies to all columns or a table of attributes. [Deprecated]
#  |
#  |      E.g., t.sum() on a Table will return a table with the sum of each column.
#  |
#  |  __getitem__(self, index_or_label)
#  |
#  |  __init__(self, labels=None, formatter=<datascience.formats.Formatter object at 0x7f8ac0932da0>)
# ...
